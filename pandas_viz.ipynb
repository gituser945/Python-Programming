# %% [markdown]
# ### Pandas Vizualization

# %%
# importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# creating dataset for this task

np.random.seed(20)
df = pd.DataFrame(np.random.randn(1000,1),index = pd.date_range("2021-09-01",periods = 1000),columns = ['Data'])

# %%
df
# Out:
#                 Data
# 2021-09-01  0.883893
# 2021-09-02  0.195865
# 2021-09-03  0.357537
# 2021-09-04 -2.343262
# 2021-09-05 -1.084833
# ...              ...
# 2024-05-23 -0.771658
# 2024-05-24 -0.838457
# 2024-05-25 -0.014126
# 2024-05-26  2.077352
# 2024-05-27  0.456634
#
# [1000 rows x 1 columns]

# %%
# let's visualize in order to see the trends

df.plot(figsize = (10,5))
# Out:
# <AxesSubplot:>

# %%
df.cumsum().plot(figsize =(10,5))
# Out:
# <AxesSubplot:>

# %%
# loading iris data

iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
gf = iris.plot(figsize = (10,5),title = "Iris Dataset")
gf.set_xlabel("Index")
gf.set_ylabel("This is Y axis")
# Out:
# Text(0, 0.5, 'This is Y axis')

# %%
# fetching one record from dataset

iris.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
iris.iloc[0][0:4]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
iris.iloc[0][0:4].plot(kind = 'bar',figsize = (10,5))
# Out:
# <AxesSubplot:>

# %%
# loading titanic dataset

titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# ploting class 

titanic['pclass'].plot(kind = 'bar',figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
df1 = pd.DataFrame(np.random.rand(10,4),columns = ['a','b','c','d'])

# %%
df1
# Out:
#           a         b         c         d
# 0  0.053299  0.615018  0.677358  0.754156
# 1  0.012843  0.411595  0.642918  0.165730
# 2  0.345043  0.845896  0.571938  0.712259
# 3  0.288993  0.436035  0.176608  0.984243
# 4  0.959149  0.791747  0.130269  0.253556
# 5  0.699920  0.143349  0.061057  0.702310
# 6  0.950065  0.679900  0.864797  0.792697
# 7  0.411256  0.885654  0.006225  0.468609
# 8  0.256099  0.596760  0.740378  0.153784
# 9  0.800812  0.072402  0.921165  0.297412

# %%
df1.plot(kind = 'bar',figsize = (10,6))
# Out:
# <AxesSubplot:>

# %%
# rotating the graph

df1.plot(kind = 'barh',figsize = (10,6))
# Out:
# <AxesSubplot:>

# %%
# plotting histogram

iris.plot(kind = 'hist',figsize = (10,6))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# plotting sepal length distribution

iris['sepal_length'].plot(kind = 'hist',figsize = (10,6))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris['sepal_length'].plot(kind = 'density',figsize = (10,5))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.plot(kind = 'hist',stacked = True,bins=100,figsize=(10,6))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.hist(figsize = (15,10),color = 'olive',grid = False)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
# checking relationship between two variables

iris.plot.scatter(x = 'sepal_width',y = 'petal_width',figsize = (10,6))
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
iris.plot.scatter(x = 'sepal_width',y = 'petal_width',c = 'petal_length',figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
iris.plot.scatter(x = 'sepal_width',y = 'petal_width',c = 'petal_length',figsize=(10,6),label = 'Points',s=80)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
iris.plot.hexbin(x = 'sepal_length',y = 'sepal_width',label = 'Hexabin Graph',gridsize = 10,figsize = (10,7))
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df1.iloc[0].plot.pie(figsize = (10,6))
# Out:
# <AxesSubplot:ylabel='0'>

# %%
# plotting scatter matrix

pd.plotting.scatter_matrix(iris,figsize = (10,6))
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
# if we want to get density plot

pd.plotting.scatter_matrix(iris,figsize = (10,8),diagonal = 'density')
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...
